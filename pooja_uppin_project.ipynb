# %%
import pandas as pd
url="https://raw.githubusercontent.com/Naresh312143/mahalingpur-python-ml/refs/heads/main/Indian%20Unicorn%20startups%202023%20updated.csv"
df=pd.read_csv(url)
df.head()
# Out:
#    No.    Company                       Sector  Entry Valuation^^ ($B)  \
# 0    1     InMobi          Adtech - Mobile Ads                     1.0
# 1    2  Flipkart^                   E-Commerce                     1.0
# 2    3   Mu Sigma             SaaS - Analytics                     1.0
# 3    4  Snapdeal*                   E-Commerce                     1.8
# 4    5     PayTM^  Fintech - Payments & Wallet                     1.7
#
#    Valuation ($B)     Entry             Location  \
# 0             1.0  Sep/2011  Bangalore/Singapore
# 1            37.6  Feb/2012  Bangalore/Singapore
# 2             1.5  Feb/2013    Bangalore/Chicago
# 3             2.4  Oct/2014                Delhi
# 4            16.0  Feb/2015                Noida
#
#                                     Select Investors
# 0                  KPCB, Sherpalo Ventures, SoftBank
# 1    Accel, Tiger Global, Naspers, SoftBank, Tencent
# 2           Accel, Sequoia Capital, General Atlantic
# ...

# %%
import pandas as pd
url="https://raw.githubusercontent.com/Naresh312143/mahalingpur-python-ml/refs/heads/main/Indian%20Unicorn%20startups%202023%20updated.csv"
df=pd.read_csv(url)
df.head(5)
# Out:
#    No.    Company                       Sector  Entry Valuation^^ ($B)  \
# 0    1     InMobi          Adtech - Mobile Ads                     1.0
# 1    2  Flipkart^                   E-Commerce                     1.0
# 2    3   Mu Sigma             SaaS - Analytics                     1.0
# 3    4  Snapdeal*                   E-Commerce                     1.8
# 4    5     PayTM^  Fintech - Payments & Wallet                     1.7
#
#    Valuation ($B)     Entry             Location  \
# 0             1.0  Sep/2011  Bangalore/Singapore
# 1            37.6  Feb/2012  Bangalore/Singapore
# 2             1.5  Feb/2013    Bangalore/Chicago
# 3             2.4  Oct/2014                Delhi
# 4            16.0  Feb/2015                Noida
#
#                                     Select Investors
# 0                  KPCB, Sherpalo Ventures, SoftBank
# 1    Accel, Tiger Global, Naspers, SoftBank, Tencent
# 2           Accel, Sequoia Capital, General Atlantic
# ...

# %%
print("data types")
df.dtypes
# Out:
# data types
# No.                         int64
# Company                    object
# Sector                     object
# Entry Valuation^^ ($B)    float64
# Valuation ($B)            float64
# Entry                      object
# Location                   object
# Select Investors           object
# dtype: object

# %%
missing_values=df.isnull()
print(missing_values)
# Out:
#        No.  Company  Sector  Entry Valuation^^ ($B)  Valuation ($B)  Entry  \
# 0    False    False   False                   False           False  False
# 1    False    False   False                   False           False  False
# 2    False    False   False                   False           False  False
# 3    False    False   False                   False           False  False
# 4    False    False   False                   False           False  False
# ..     ...      ...     ...                     ...             ...    ...
# 97   False    False   False                   False           False  False
# 98   False    False   False                   False           False  False
# 99   False    False   False                   False           False  False
# 100  False    False   False                   False           False  False
# 101  False    False   False                   False           False  False
#
#      Location  Select Investors
# 0       False             False
# ...

# %%
duplicate_rows=df.duplicated()
print(duplicate_rows)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# Length: 102, dtype: bool

# %%
describe_method=df.describe(include='all')
print(describe_method)
# Out:
#                No. Company  Sector  Entry Valuation^^ ($B)  Valuation ($B)  \
# count   102.000000     102     102              102.000000      102.000000
# unique         NaN     102      75                     NaN             NaN
# top            NaN  InMobi  Edtech                     NaN             NaN
# freq           NaN       1       5                     NaN             NaN
# mean     51.500000     NaN     NaN                1.547549        3.398020
# std      29.588849     NaN     NaN                1.138013        4.710657
# min       1.000000     NaN     NaN                1.000000        0.568000
# 25%      26.250000     NaN     NaN                1.000000        1.200000
# 50%      51.500000     NaN     NaN                1.200000        1.850000
# 75%      76.750000     NaN     NaN                1.582500        3.475000
# max     102.000000     NaN     NaN               10.000000       37.600000
#
#            Entry   Location                   Select Investors
# ...

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['No.', 'Company', 'Sector', 'Entry Valuation^^ ($B)', 'Valuation ($B)',
#        'Entry', 'Location', 'Select Investors'],
#       dtype='object')

# %%
df['Entry'] = pd.to_datetime(df['Entry'])
print(df['Entry'])
# Out:
# 0     2011-09-01
# 1     2012-02-01
# 2     2013-02-01
# 3     2014-10-01
# 4     2015-02-01
#          ...
# 97    2022-06-01
# 98    2022-06-01
# 99    2022-07-01
# 100   2022-08-01
# 101   2022-09-01
# Name: Entry, Length: 102, dtype: datetime64[ns]
# /tmp/ipython-input-8-3556393008.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Entry'] = pd.to_datetime(df['Entry'])

# %%
df
# Out:
#      No.             Company                                  Sector  \
# 0      1              InMobi                     Adtech - Mobile Ads
# 1      2           Flipkart^                              E-Commerce
# 2      3            Mu Sigma                        SaaS - Analytics
# 3      4           Snapdeal*                              E-Commerce
# 4      5              PayTM^             Fintech - Payments & Wallet
# ..   ...                 ...                                     ...
# 97    98             Purplle  E-Commerce - Personal Care & Cosmetics
# 98    99         Leadsquared                              SaaS - CRM
# 99   100             OneCard                  Fintech - Credit Cards
# 100  101          Shiprocket         Aggregator - Logistics Services
# 101  102  Molbio Diagnostics                Healthtech - Diagnostics
#
#      Entry Valuation^^ ($B)  Valuation ($B)      Entry             Location  \
# ...

# %%
df['Primary City'] = df['Location'].str.split(',').str[0]
df.head()
# Out:
#    No.    Company                       Sector  Entry Valuation^^ ($B)  \
# 0    1     InMobi          Adtech - Mobile Ads                     1.0
# 1    2  Flipkart^                   E-Commerce                     1.0
# 2    3   Mu Sigma             SaaS - Analytics                     1.0
# 3    4  Snapdeal*                   E-Commerce                     1.8
# 4    5     PayTM^  Fintech - Payments & Wallet                     1.7
#
#    Valuation ($B)      Entry             Location  \
# 0             1.0 2011-09-01  Bangalore/Singapore
# 1            37.6 2012-02-01  Bangalore/Singapore
# 2             1.5 2013-02-01    Bangalore/Chicago
# 3             2.4 2014-10-01                Delhi
# 4            16.0 2015-02-01                Noida
#
#                                     Select Investors         Primary City
# 0                  KPCB, Sherpalo Ventures, SoftBank  Bangalore/Singapore
# 1    Accel, Tiger Global, Naspers, SoftBank, Tencent  Bangalore/Singapore
# ...

# %%
df['Valuation_Growth'] = df['Valuation ($B)'] / df['Entry Valuation^^ ($B)']
df.head()
# Out:
#    No.    Company                       Sector  Entry Valuation^^ ($B)  \
# 0    1     InMobi          Adtech - Mobile Ads                     1.0
# 1    2  Flipkart^                   E-Commerce                     1.0
# 2    3   Mu Sigma             SaaS - Analytics                     1.0
# 3    4  Snapdeal*                   E-Commerce                     1.8
# 4    5     PayTM^  Fintech - Payments & Wallet                     1.7
#
#    Valuation ($B)      Entry             Location  \
# 0             1.0 2011-09-01  Bangalore/Singapore
# 1            37.6 2012-02-01  Bangalore/Singapore
# 2             1.5 2013-02-01    Bangalore/Chicago
# 3             2.4 2014-10-01                Delhi
# 4            16.0 2015-02-01                Noida
#
#                                     Select Investors         Primary City  \
# 0                  KPCB, Sherpalo Ventures, SoftBank  Bangalore/Singapore
# 1    Accel, Tiger Global, Naspers, SoftBank, Tencent  Bangalore/Singapore
# ...

# %%
name_count = df['Select Investors'].count()
print(name_count)
# Out:
# 102

# %%
plt.boxplot(df['Valuation ($B)'])
plt.title('Valuation Boxplot')
plt.ylabel('Valuation ($B)')

plt.show()

# %%
import matplotlib.pyplot as plt
Valuation_growth=df['Entry Valuation^^ ($B)']
print(Valuation_growth)
plt.hist(Valuation_growth,bins=5,color='coral',edgecolor='black')
plt.show()
# Out:
# 0      1.00
# 1      1.00
# 2      1.00
# 3      1.80
# 4      1.70
#        ...
# 97     1.10
# 98     1.00
# 99     1.30
# 100    1.23
# 101    1.53
# Name: Entry Valuation^^ ($B), Length: 102, dtype: float64

# %%
top_10_sectors = df['Sector'].value_counts().head(10)
top_10_sectors.plot(kind='bar', figsize=(8,6))
plt.title('Top 10 Sectors by Count')
plt.xticks(rotation=40)
plt.show()

# %%
import matplotlib.pyplot as plt
sector_counts = df['Sector'].value_counts()
top_10_sectors = sector_counts.head(10)
plt.figure(figsize=(8,8))
top_10_sectors.plot(kind='pie', autopct='%1.1f%%')
plt.title('Top 10 Sectors by Count')
plt.ylabel('')
plt.show()

# %%
plt.scatter(df['Select Investors'], df['Valuation ($B)'], alpha=0.6, s=60, color='purple')
plt.title('Number of Investors vs Valuation', fontweight='bold')
plt.xlabel('Number of Investors')
plt.ylabel('Valuation ($B)')
plt.show()

# %%
df.count()
# Out:
# No.                       102
# Company                   102
# Sector                    102
# Entry Valuation^^ ($B)    102
# Valuation ($B)            102
# Entry                     102
# Location                  102
# Select Investors          102
# Primary City              102
# Valuation_Growth          102
# dtype: int64

# %%
total_valuation=df['Valuation ($B)'].sum()
print(total_valuation)
# Out:
# 346.598

# %%
avg_valuation=df['Valuation ($B)'].mean()
print(avg_valuation)
# Out:
# 3.3980196078431373

# %%
first_entry=df['Location'].iloc[0]
print(first_entry)
# Out:
# Bangalore/Singapore

# %%
last_entry=df['Valuation ($B)'].iloc[101]
print(last_entry)
# Out:
# 1.53

# %%
avg_valuation_per_sector = df.groupby('Sector')['Valuation ($B)'].mean().sort_values(ascending=False).head(10)
print(avg_valuation_per_sector)
avg_valuation_per_sector.head(10).plot(kind='bar')
plt.xlabel("Sector")
plt.ylabel("Average Valuation ($B)")
plt.title("Average Valuation per Sector")
plt.show()
# Out:
# Sector
# Fintech - Payments & Wallet                 16.000
# E-Commerce                                  11.025
# Web3 Infrastructure - Dapps                 10.000
# Proptech - Hotel Booking                     9.600
# Foodtech                                     8.050
# Fintech - Payment Gateway                    7.500
# Fintech - Payments                           7.400
# Mobility - Ride Aggregator                   7.300
# Fintech - Payments & Credit Card Rewards     6.400
# Edtech                                       5.720
# Name: Valuation ($B), dtype: float64

# %%
city_counts = df['Primary City'].value_counts().head(10)
bars = plt.bar(city_counts.index, city_counts.values, color='coral')
plt.title('Top Cities by Number of Unicorns', fontsize=14, fontweight='bold')
plt.xlabel('Cities')
plt.ylabel('Number of Unicorns')
plt.xticks(rotation=45)
plt.show()

# %%
df['Entry Year'] = df['Entry'].dt.year
entry_year_counts = df['Entry Year'].value_counts().sort_index()
entry_year_counts.plot(kind='bar', figsize=(8,6))
plt.title('Entry Year Trends')
plt.xlabel('Entry Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
avg_val_by_year = df.groupby('Entry Year')['Valuation ($B)'].mean()
print(avg_val_by_year)
plt.bar(avg_val_by_year.index, avg_val_by_year.values, color='gold')
plt.title('Average Valuation by Entry Year', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Average Valuation ($B)')
plt.show()
# Out:
# Entry Year
# 2011     1.000000
# 2012    37.600000
# 2013     1.500000
# 2014     2.400000
# 2015     7.550000
# 2016     1.250000
# 2018     6.987500
# 2019     3.522222
# 2020     4.710000
# 2021     2.284955
# 2022     1.721905
# Name: Valuation ($B), dtype: float64

# %%
df['Investor Count'] = df['Select Investors'].str.split(',').str.len()
year_investor = df.groupby('Entry Year')['Investor Count'].mean()
plt.plot(year_investor.index, year_investor.values, marker='o', linewidth=2, markersize=6, color='red')
plt.title('Average Investor Count by Entry Year', fontweight='bold')
plt.xlabel('Entry Year')
plt.ylabel('Average Number of Investors')
plt.show()

# %%
print("Total Market Value:", df['Valuation ($B)'].sum())
print("Average Valuation:", df['Valuation ($B)'].mean())
print("Median Valuation:", df['Valuation ($B)'].median())
# Out:
# Total Market Value: 346.598
# Average Valuation: 3.3980196078431373
# Median Valuation: 1.85

# %%
print("SECTOR Diversity")
print(len(df['Sector'].unique()))
# Out:
# SECTOR Diversity
# 75

# %%
print(len(df['Primary City'].unique()))
# Out:
# 27

# %%
print("No of unicons after 2020")
print((df['Entry Year'] >= 2020).sum())
# Out:
# No of unicons after 2020
# 75

# %%
print("\n5. INVESTMENT INSIGHTS:")
print("Average Investors per Unicorn:", df['Investor Count'].mean())
print("Average Valuation Growth:", df['Valuation_Growth'].mean())
# Out:
# 5. INVESTMENT INSIGHTS:
# Average Investors per Unicorn: 4.294117647058823
# Average Valuation Growth: 2.4932787963344363

# %%
import pandas as pd
url="https://raw.githubusercontent.com/Naresh312143/mahalingpur-python-ml/refs/heads/main/Indian%20Unicorn%20startups%202023%20updated.csv"
df=pd.read_csv(url)
df.head()
# Out:
#    No.    Company                       Sector  Entry Valuation^^ ($B)  \
# 0    1     InMobi          Adtech - Mobile Ads                     1.0
# 1    2  Flipkart^                   E-Commerce                     1.0
# 2    3   Mu Sigma             SaaS - Analytics                     1.0
# 3    4  Snapdeal*                   E-Commerce                     1.8
# 4    5     PayTM^  Fintech - Payments & Wallet                     1.7
#
#    Valuation ($B)     Entry             Location  \
# 0             1.0  Sep/2011  Bangalore/Singapore
# 1            37.6  Feb/2012  Bangalore/Singapore
# 2             1.5  Feb/2013    Bangalore/Chicago
# 3             2.4  Oct/2014                Delhi
# 4            16.0  Feb/2015                Noida
#
#                                     Select Investors
# 0                  KPCB, Sherpalo Ventures, SoftBank
# 1    Accel, Tiger Global, Naspers, SoftBank, Tencent
# 2           Accel, Sequoia Capital, General Atlantic
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   No.                     102 non-null    int64
#  1   Company                 102 non-null    object
#  2   Sector                  102 non-null    object
#  3   Entry Valuation^^ ($B)  102 non-null    float64
#  4   Valuation ($B)          102 non-null    float64
#  5   Entry                   102 non-null    object
#  6   Location                102 non-null    object
#  7   Select Investors        102 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 6.5+ KB

# %%
df_encoded=pd.get_dummies(df,drop_first=True)
df_encoded.head()
# Out:
#    No.  Entry Valuation^^ ($B)  Valuation ($B)  Company_Amagi Media Labs  \
# 0    1                     1.0             1.0                     False
# 1    2                     1.0            37.6                     False
# 2    3                     1.0             1.5                     False
# 3    4                     1.8             2.4                     False
# 4    5                     1.7            16.0                     False
#
#    Company_Apna.co  Company_BYJUS  Company_BharatPe  Company_BigBasket  \
# 0            False          False             False              False
# 1            False          False             False              False
# 2            False          False             False              False
# 3            False          False             False              False
# 4            False          False             False              False
#
#    Company_BillDesk  Company_BlackBuck  ...  \
# 0             False              False  ...
# ...

# %%
df.columns
# Out:
# Index(['No.', 'Company', 'Sector', 'Entry Valuation^^ ($B)', 'Valuation ($B)',
#        'Entry', 'Location', 'Select Investors'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# No.                       0
# Company                   0
# Sector                    0
# Entry Valuation^^ ($B)    0
# Valuation ($B)            0
# Entry                     0
# Location                  0
# Select Investors          0
# dtype: int64

# %%
df_encoded=pd.get_dummies(df,drop_first=True)
df_encoded.head()
# Out:
#    No.  Entry Valuation^^ ($B)  Valuation ($B)  Company_Amagi Media Labs  \
# 0    1                     1.0             1.0                     False
# 1    2                     1.0            37.6                     False
# 2    3                     1.0             1.5                     False
# 3    4                     1.8             2.4                     False
# 4    5                     1.7            16.0                     False
#
#    Company_Apna.co  Company_BYJUS  Company_BharatPe  Company_BigBasket  \
# 0            False          False             False              False
# 1            False          False             False              False
# 2            False          False             False              False
# 3            False          False             False              False
# 4            False          False             False              False
#
#    Company_BillDesk  Company_BlackBuck  ...  \
# 0             False              False  ...
# ...

# %%
x=df_encoded.drop(columns=['Valuation ($B)'])
y=df_encoded['Valuation ($B)']

# %%
y
# Out:
# 0       1.00
# 1      37.60
# 2       1.50
# 3       2.40
# 4      16.00
#        ...
# 97      1.10
# 98      1.00
# 99      1.30
# 100     1.23
# 101     1.53
# Name: Valuation ($B), Length: 102, dtype: float64

# %%
x
# Out:
#      No.  Entry Valuation^^ ($B)  Company_Amagi Media Labs  Company_Apna.co  \
# 0      1                    1.00                     False            False
# 1      2                    1.00                     False            False
# 2      3                    1.00                     False            False
# 3      4                    1.80                     False            False
# 4      5                    1.70                     False            False
# ..   ...                     ...                       ...              ...
# 97    98                    1.10                     False            False
# 98    99                    1.00                     False            False
# 99   100                    1.30                     False            False
# 100  101                    1.23                     False            False
# 101  102                    1.53                     False            False
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
x
# Out:
#      No.  Entry Valuation^^ ($B)  Company_Amagi Media Labs  Company_Apna.co  \
# 0      1                    1.00                     False            False
# 1      2                    1.00                     False            False
# 2      3                    1.00                     False            False
# 3      4                    1.80                     False            False
# 4      5                    1.70                     False            False
# ..   ...                     ...                       ...              ...
# 97    98                    1.10                     False            False
# 98    99                    1.00                     False            False
# 99   100                    1.30                     False            False
# 100  101                    1.23                     False            False
# 101  102                    1.53                     False            False
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42)
print(x_train)
print(y_train)
# Out:
# [[ 0.08490853 -0.48352072 -0.09950372 ... -0.09950372 -0.09950372
#   -0.09950372]
#  [-0.96795727 -0.48352072 -0.09950372 ... -0.09950372 10.04987562
#   -0.09950372]
#  [ 0.59435972 -0.1302952  -0.09950372 ... -0.09950372 -0.09950372
#   -0.09950372]
#  ...
#  [-1.23966457 -0.04198882 -0.09950372 ... -0.09950372 -0.09950372
#   -0.09950372]
#  [ 1.40948163 -0.48352072 10.04987562 ... -0.09950372 -0.09950372
#   -0.09950372]
#  [ 0.01698171 -0.1302952  -0.09950372 ... -0.09950372 -0.09950372
#   -0.09950372]]
# 53    1.0
# 22    2.0
# 68    1.4
# 44    5.6
# 98    1.0
#      ...
# 60    3.2
# 71    1.2
# 14    3.5
# 92    1.0
# 51    1.5
# Name: Valuation ($B), Length: 81, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([2.75273185, 2.24885009, 2.52735157, 3.16273596, 3.19026102,
#        2.65659551, 2.30472812, 3.15505394, 2.90557677, 6.19547348,
#        2.78513104, 2.98189814, 1.9561257 , 2.92348174, 2.41789083,
#        3.14979211, 2.06905087, 3.12076393, 3.40186966, 2.78035649,
#        2.12870586])

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)



print("mean squared error:",mse)
print("root mean squared error:",rmse)
# Out:
# mean squared error: 36.93788205924401
# root mean squared error: 6.0776543221249435

# %%
import pandas as pd
url="https://raw.githubusercontent.com/Naresh312143/mahalingpur-python-ml/refs/heads/main/Indian%20Unicorn%20startups%202023%20updated.csv"
df=pd.read_csv(url)
df.head()
# Out:
#    No.    Company                       Sector  Entry Valuation^^ ($B)  \
# 0    1     InMobi          Adtech - Mobile Ads                     1.0
# 1    2  Flipkart^                   E-Commerce                     1.0
# 2    3   Mu Sigma             SaaS - Analytics                     1.0
# 3    4  Snapdeal*                   E-Commerce                     1.8
# 4    5     PayTM^  Fintech - Payments & Wallet                     1.7
#
#    Valuation ($B)     Entry             Location  \
# 0             1.0  Sep/2011  Bangalore/Singapore
# 1            37.6  Feb/2012  Bangalore/Singapore
# 2             1.5  Feb/2013    Bangalore/Chicago
# 3             2.4  Oct/2014                Delhi
# 4            16.0  Feb/2015                Noida
#
#                                     Select Investors
# 0                  KPCB, Sherpalo Ventures, SoftBank
# 1    Accel, Tiger Global, Naspers, SoftBank, Tencent
# 2           Accel, Sequoia Capital, General Atlantic
# ...

# %%
df.describe()
# Out:
#               No.  Entry Valuation^^ ($B)  Valuation ($B)
# count  102.000000              102.000000      102.000000
# mean    51.500000                1.547549        3.398020
# std     29.588849                1.138013        4.710657
# min      1.000000                1.000000        0.568000
# 25%     26.250000                1.000000        1.200000
# 50%     51.500000                1.200000        1.850000
# 75%     76.750000                1.582500        3.475000
# max    102.000000               10.000000       37.600000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   No.                     102 non-null    int64
#  1   Company                 102 non-null    object
#  2   Sector                  102 non-null    object
#  3   Entry Valuation^^ ($B)  102 non-null    float64
#  4   Valuation ($B)          102 non-null    float64
#  5   Entry                   102 non-null    object
#  6   Location                102 non-null    object
#  7   Select Investors        102 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 6.5+ KB

# %%
df.isnull().sum()
# Out:
# No.                       0
# Company                   0
# Sector                    0
# Entry Valuation^^ ($B)    0
# Valuation ($B)            0
# Entry                     0
# Location                  0
# Select Investors          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   No.                     102 non-null    int64
#  1   Company                 102 non-null    object
#  2   Sector                  102 non-null    object
#  3   Entry Valuation^^ ($B)  102 non-null    float64
#  4   Valuation ($B)          102 non-null    float64
#  5   Entry                   102 non-null    object
#  6   Location                102 non-null    object
#  7   Select Investors        102 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 6.5+ KB

# %%
from sklearn.preprocessing import StandardScaler
x=df[['Entry Valuation^^ ($B)']].values
y=df[['Valuation ($B)']].values
sc_x=StandardScaler()

sc_y=StandardScaler()
x_scaled=sc_x.fit_transform(x)
y_scaled=sc_y.fit_transform(y)

# %%
y_scaled
# Out:
# array([[-5.11576536e-01],
#        [ 7.29640851e+00],
#        [-4.04910074e-01],
#        [-2.12910442e-01],
#        [ 2.68841733e+00],
#        [ 8.32420889e-01],
#        [-4.04910074e-01],
#        [ 4.27088332e-01],
#        [-4.90243244e-01],
#        [-4.26243367e-01],
#        [ 3.96841488e+00],
#        [-8.49106870e-02],
#        [ 1.55775283e+00],
#        [-2.12910442e-01],
#        [ 2.17557753e-02],
#        [ 1.32308662e+00],
#        [-6.35773946e-02],
#        [-3.83576782e-01],
#        [-8.49106870e-02],
#        [-4.90243244e-01],
#        [-2.98243612e-01],
#        [ 9.81753936e-01],
#        [-2.98243612e-01],
#        [ 3.41755162e-01],
#        [-4.90243244e-01],
#        [ 3.41755162e-01],
#        [ 2.35088700e-01],
#        [ 3.41755162e-01],
#        [-3.40910197e-01],
#        [ 4.69754917e-01],
#        [ 4.22482851e-04],
#        [ 8.75087474e-01],
#        [-2.09108096e-02],
#        [ 1.83508564e+00],
#        [-4.04910074e-01],
# ...

# %%
y_scaled=y_scaled.ravel()

# %%
from sklearn.svm import SVR
svr=SVR(kernel='rbf',C=100, epsilon=0.1)
svr.fit(x_scaled,y_scaled)
# Out:
# SVR(C=100)

# %%
y_pred_scaled=svr.predict(x_scaled)
y_pred=sc_y.inverse_transform(y_pred_scaled.reshape(-1,1))

# %%
y_pred_scaled
# Out:
# array([-3.62741390e-01, -3.62741390e-01, -3.62741390e-01, -3.10353911e-02,
#        -1.05403462e-01, -1.85508417e-01, -3.62741390e-01, -3.62741390e-01,
#        -3.90045672e-01, -3.26112546e-01, -3.62741390e-01,  2.86306326e-02,
#        -3.26112546e-01, -3.62741390e-01, -2.61939212e-01,  1.22331061e+00,
#        -3.62741390e-01, -1.85508417e-01, -1.85508417e-01, -3.90045672e-01,
#        -3.90045672e-01, -3.62741390e-01, -3.62741390e-01, -3.62741390e-01,
#        -3.90045672e-01, -3.90045672e-01, -3.90045672e-01, -1.85508417e-01,
#        -3.93146580e-01,  6.64134514e-02, -3.26112546e-01, -3.62741390e-01,
#        -3.62741390e-01,  1.73501868e+00, -3.62741390e-01, -3.62741390e-01,
#        -3.62741390e-01,  2.86306326e-02, -3.71280770e-01, -3.62741390e-01,
#        -3.26112546e-01, -1.05403462e-01,  7.80784927e-02,  6.30942340e-02,
#        -2.61939212e-01, -3.62741390e-01,  7.80784927e-02, -3.26112546e-01,
# ...

# %%
y_pred
# Out:
# array([[ 1.69766609],
#        [ 1.69766609],
#        [ 1.69766609],
#        [ 3.25254093],
#        [ 2.90393993],
#        [ 2.52844724],
#        [ 1.69766609],
#        [ 1.69766609],
#        [ 1.56967702],
#        [ 1.86936412],
#        [ 1.69766609],
#        [ 3.53222596],
#        [ 1.86936412],
#        [ 1.69766609],
#        [ 2.1701772 ],
#        [ 9.13229908],
#        [ 1.69766609],
#        [ 2.52844724],
#        [ 2.52844724],
#        [ 1.56967702],
#        [ 1.56967702],
#        [ 1.69766609],
#        [ 1.69766609],
#        [ 1.69766609],
#        [ 1.56967702],
#        [ 1.56967702],
#        [ 1.56967702],
#        [ 2.52844724],
#        [ 1.55514148],
#        [ 3.70933326],
#        [ 1.86936412],
#        [ 1.69766609],
#        [ 1.69766609],
#        [11.53093525],
#        [ 1.69766609],
#        [ 1.69766609],
#        [ 1.69766609],
#        [ 3.53222596],
#        [ 1.65763766],
#        [ 1.69766609],
#        [ 1.86936412],
# ...

# %%
dframe=pd.DataFrame({'Actual':y.ravel(),'Predicted':y_pred.ravel()})
dframe.head(15)
# Out:
#     Actual  Predicted
# 0      1.0   1.697666
# 1     37.6   1.697666
# 2      1.5   1.697666
# 3      2.4   3.252541
# 4     16.0   2.903940
# 5      7.3   2.528447
# 6      1.5   1.697666
# 7      5.4   1.697666
# 8      1.1   1.569677
# 9      1.4   1.869364
# 10    22.0   1.697666
# 11     3.0   3.532226
# 12    10.7   1.869364
# 13     2.4   1.697666
# 14     3.5   2.170177

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)

print("Mean Squared Error:", mse)
print("Root Mean Squared Error", rmse)
# Out:
# Mean Squared Error: 21.450208741916153
# Root Mean Squared Error 4.631437006147893

# %%
import pandas as pd
url="https://raw.githubusercontent.com/Naresh312143/mahalingpur-python-ml/refs/heads/main/Indian%20Unicorn%20startups%202023%20updated.csv"
df=pd.read_csv(url)
df.head()
# Out:
#    No.    Company                       Sector  Entry Valuation^^ ($B)  \
# 0    1     InMobi          Adtech - Mobile Ads                     1.0
# 1    2  Flipkart^                   E-Commerce                     1.0
# 2    3   Mu Sigma             SaaS - Analytics                     1.0
# 3    4  Snapdeal*                   E-Commerce                     1.8
# 4    5     PayTM^  Fintech - Payments & Wallet                     1.7
#
#    Valuation ($B)     Entry             Location  \
# 0             1.0  Sep/2011  Bangalore/Singapore
# 1            37.6  Feb/2012  Bangalore/Singapore
# 2             1.5  Feb/2013    Bangalore/Chicago
# 3             2.4  Oct/2014                Delhi
# 4            16.0  Feb/2015                Noida
#
#                                     Select Investors
# 0                  KPCB, Sherpalo Ventures, SoftBank
# 1    Accel, Tiger Global, Naspers, SoftBank, Tencent
# 2           Accel, Sequoia Capital, General Atlantic
# ...

# %%
df_encoded=pd.get_dummies(df,drop_first=True)
df_encoded.head()
# Out:
#    No.  Entry Valuation^^ ($B)  Valuation ($B)  Company_Amagi Media Labs  \
# 0    1                     1.0             1.0                     False
# 1    2                     1.0            37.6                     False
# 2    3                     1.0             1.5                     False
# 3    4                     1.8             2.4                     False
# 4    5                     1.7            16.0                     False
#
#    Company_Apna.co  Company_BYJUS  Company_BharatPe  Company_BigBasket  \
# 0            False          False             False              False
# 1            False          False             False              False
# 2            False          False             False              False
# 3            False          False             False              False
# 4            False          False             False              False
#
#    Company_BillDesk  Company_BlackBuck  ...  \
# 0             False              False  ...
# ...

# %%
from sklearn.preprocessing import StandardScaler
x=df_encoded.drop('Valuation ($B)',axis=1)
y=df_encoded['Valuation ($B)']
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
x=df_encoded.drop('Valuation ($B)',axis=1)
y=df_encoded['Valuation ($B)']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42)
print(x_train)
# Out:
# [[ 0.08490853 -0.48352072 -0.09950372 ... -0.09950372 -0.09950372
#   -0.09950372]
#  [-0.96795727 -0.48352072 -0.09950372 ... -0.09950372 10.04987562
#   -0.09950372]
#  [ 0.59435972 -0.1302952  -0.09950372 ... -0.09950372 -0.09950372
#   -0.09950372]
#  ...
#  [-1.23966457 -0.04198882 -0.09950372 ... -0.09950372 -0.09950372
#   -0.09950372]
#  [ 1.40948163 -0.48352072 10.04987562 ... -0.09950372 -0.09950372
#   -0.09950372]
#  [ 0.01698171 -0.1302952  -0.09950372 ... -0.09950372 -0.09950372
#   -0.09950372]]

# %%
from sklearn.tree import DecisionTreeRegressor,export_text
regression=DecisionTreeRegressor(max_depth=4,random_state=42)
regression.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=4, random_state=42)

# %%
y_pred=regression.predict(x_test)

# %%
y_pred
# Out:
# array([ 3.08780488,  1.18993333,  1.18993333,  3.08780488,  3.08780488,
#         3.08780488,  1.18993333,  3.08780488,  3.08780488, 37.6       ,
#         3.08780488,  3.08780488,  1.18993333,  2.43333333,  2.43333333,
#         3.08780488,  1.18993333,  3.08780488,  3.08780488,  3.08780488,
#         1.18993333])

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
print("mean squared error:",mse)
print("root mean squared error:",rmse)
# Out:
# mean squared error: 99.63591532048332
# root mean squared error: 9.981779166084738

# %%
from collections import Counter
investors = df['Select Investors'].str.split(',\s*').explode()
investor_counts = Counter(investors)
top_investors = pd.DataFrame(investor_counts.most_common(10), columns=['Investor', 'Number of Unicorns'])
plt.figure(figsize=(12, 6))
sns.barplot(x='Number of Unicorns', y='Investor', data=top_investors, palette='viridis')
plt.title('Top 10 Investors in Indian Unicorns')
plt.xlabel('Number of Unicorns')
plt.ylabel('Investor')
plt.show()
# Out:
# /tmp/ipython-input-50-2871697892.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Number of Unicorns', y='Investor', data=top_investors, palette='viridis')

# %% [markdown]
# *   # ***`SUMMARY`***
#
#
# * Data Cleaning: Missing values were imputed, columns were cleaned, and new columns like Entry Year, Valuation_Growth, and Primary_City were added for further analysis.
#
# * Sector Insights: E-commerce, Fintech, and Technology dominate the unicorn ecosystem. Sectors like Fintech have the highest average valuations.
#
# * City Insights: Bangalore, Delhi, and Mumbai are the top cities with the highest number of unicorns. Bangalore leads in unicorn count, while Delhi has higher average valuations.
#
# * Valuation Trends: Unicorns have grown rapidly post-2015, with significant valuation increases post-2020. There's a positive correlation between the number of investors and higher valuations.
#
# * Key Insights:
#
#       Top Sectors: Fintech, E-commerce, AI/Tech.
#
#       Top Cities: Bangalore, Delhi, Mumbai.
#
#       Valuation Growth: Rapid growth in unicorn valuations, especially in recent years.
